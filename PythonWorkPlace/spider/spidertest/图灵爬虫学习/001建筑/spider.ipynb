# %%
import requests

cookies = {
    'Hm_lvt_03b8714a30a2e110b8a13db120eb6774': '1741266674',
    'HMACCOUNT': '37FE193F4E19BA6C',
    'HWWAFSESTIME': '1741266669755',
    'HWWAFSESID': '0baec88098b1809b9e',
    'Hm_lpvt_03b8714a30a2e110b8a13db120eb6774': '1741266683',
}

headers = {
    'Connection': 'keep-alive',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="99", "Google Chrome";v="99"',
    'page': 'search-enterprise',
    'deviceType': 'PC',
    'sec-ch-ua-mobile': '?0',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36',
    'Content-Type': 'application/json;charset=UTF-8',
    'Accept': 'application/json, text/plain, */*',
    'timestamp': '1741270284834',
    'sign': 'edccc3902b024b654e3fd76b14a96a71',
    'sec-ch-ua-platform': '"Windows"',
    'Origin': 'https://www.jiansheku.com',
    'Sec-Fetch-Site': 'same-site',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://www.jiansheku.com/',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    # 'Cookie': 'Hm_lvt_03b8714a30a2e110b8a13db120eb6774=1741266674; HMACCOUNT=37FE193F4E19BA6C; HWWAFSESTIME=1741266669755; HWWAFSESID=0baec88098b1809b9e; Hm_lpvt_03b8714a30a2e110b8a13db120eb6774=1741266683',
}

json_data = {
    'eid': '',
    'achievementQueryType': 'and',
    'achievementQueryDto': [],
    'personnelQueryDto': {
        'queryType': 'and',
    },
    'aptitudeQueryDto': {
        'queryType': 'and',
        'nameStr': '',
        'aptitudeQueryType': 'and',
        'businessScopeQueryType': 'or',
        'filePlaceType': '1',
        'aptitudeDtoList': [
            {
                'codeStr': '',
                'queryType': 'and',
                'aptitudeType': 'qualification',
            },
        ],
        'aptitudeSource': 'new',
    },
    'page': {
        'page': 3,
        'limit': 20,
        'field': '',
        'order': '',
    },
}

response = requests.post('https://capi.jiansheku.com/nationzj/enterprice/page', cookies=cookies, headers=headers, json=json_data).json()

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"eid":"","achievementQueryType":"and","achievementQueryDto":[],"personnelQueryDto":{"queryType":"and"},"aptitudeQueryDto":{"queryType":"and","nameStr":"","aptitudeQueryType":"and","businessScopeQueryType":"or","filePlaceType":"1","aptitudeDtoList":[{"codeStr":"","queryType":"and","aptitudeType":"qualification"}],"aptitudeSource":"new"},"page":{"page":3,"limit":20,"field":"","order":""}}'
#response = requests.post('https://capi.jiansheku.com/nationzj/enterprice/page', cookies=cookies, headers=headers, data=data)

# %%
print(response)
# Out:
# {'code': 200, 'msg': '操作成功', 'data': {'total': 129613527, 'field': '', 'limit': 20, 'page': 3, 'list': [{'registerCity': None, 'projectCount': 12422, 'isISO': None, 'county': None, 'jdztzgCount': None, 'cityId': None, 'source': None, 'zzSxbzxCount': None, 'filePlaceType': None, 'recentlyCount': 3285, 'roadConservancy': 0, 'liceCertNo': None, 'province': None, 'regionInfo': None, 'threePersonnelCount': 1, 'zzRiskBidCount': None, 'certData': None, 'id': '124182757', 'supplierCount': 10, 'businessAddress': '广州市天河区黄埔大道中309号自编3-09A', 'formerName': '广东省建筑艺术设计公司,广东建筑艺术设计院', 'jmzyCount': None, 'actualCapi': None, 'businessScope': None, 'registerProvince': None, 'provinceId': None, 'bidMaxAmount': 80000.0, 'logoUrl': '', 'skyCount': 4762, 'labels': [{'pcode': '4_', 'level': 2, 'linkBizId': None, 'num': 1, 'orderNum': 2, 'remark': '严重行政处罚，是指有关行政部门处以企业暂停投标资格、暂停承揽新业务的行政处罚。原因包括但不限于企业存在围标串标、克扣或拖欠劳动者报酬、出现重大安全事故等异常行为导致企业无法承揽工程项目，产生重大经营风险', 'isLeaf': 1, 'companyId': 124182757, 'bgColor': '#FFF3F3', '
# ...
