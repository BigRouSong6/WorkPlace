# %%
# https://www.oklink.com/

# %%
import requests

cookies = {
    'aliyungf_tc': '444c0111982663bc9bbdae21aaf3cf6bde0b9a71cdcef0880ee6c56a1183d3aa',
    'traceId': '2920116786523250001',
    'devId': '442df63b-8674-4e7c-8c0a-6b1bb61a8554',
    'ok_site_info': '9FjOikHdpRnblJCLiskTJx0SPJiOiUGZvNmIsIiTDJiOi42bpdWZyJye',
    'locale': 'zh_CN',
    'ok-exp-time': '1741678652333',
    'okg.currentMedia': 'xl',
    'oklink.unaccept_cookie': '1',
    '_monitor_extras': '{"deviceId":"5CL2_9Uvi7_fXD-DVrKD2I","eventId":10,"sequenceNumber":10}',
    'amp_d77757': '442df63b-8674-4e7c-8c0a-6b1bb61a8554...1im226hrf.1im227r55.9.0.9',
    'ok-ses-id': 'U6y0YOKMz+8awzD5vJTz2YuTNsj882UVygH29JaGD4mTGakhdUbg3cdediVORDHUZL0Fxvh5kGhHfrn5hoGCg7RCHwN7Geqm5btIGmZ3FKFBK9Rq9KinqSqfU5fLA1mc',
}

headers = {
    'authority': 'www.oklink.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="99", "Google Chrome";v="99"',
    'x-locale': 'zh_CN',
    'x-apikey': 'LWIzMWUtNDU0Ny05Mjk5LWI2ZDA3Yjc2MzFhYmEyYzkwM2NjfDI4NTI3OTIzNzcwMzc4Njk=',
    'x-cdn': 'https://static.oklink.com',
    'ok-verify-token': 'c51eb362-44da-4d1c-9874-8079f6db0807',
    'x-site-info': '9FjOikHdpRnblJCLiskTJx0SPJiOiUGZvNmIsIiTDJiOi42bpdWZyJye',
    'ok-verify-sign': 'SWsQfrRDfW6qdRcjXU8zu2KJ9JyveOuw6geLSCKpcrc=',
    'sec-ch-ua-platform': '"Windows"',
    'ok-timestamp': '1741681265936',
    'devid': '442df63b-8674-4e7c-8c0a-6b1bb61a8554',
    'app-type': 'web',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36',
    'accept': 'application/json',
    'x-utc': '8',
    'x-zkdex-env': '0',
    'x-id-group': '2920116786523250001-c-13',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.oklink.com/zh-hans/btc/tx-list/page/12',
    'accept-language': 'zh-CN,zh;q=0.9',
    # 'cookie': 'aliyungf_tc=444c0111982663bc9bbdae21aaf3cf6bde0b9a71cdcef0880ee6c56a1183d3aa; traceId=2920116786523250001; devId=442df63b-8674-4e7c-8c0a-6b1bb61a8554; ok_site_info=9FjOikHdpRnblJCLiskTJx0SPJiOiUGZvNmIsIiTDJiOi42bpdWZyJye; locale=zh_CN; ok-exp-time=1741678652333; okg.currentMedia=xl; oklink.unaccept_cookie=1; _monitor_extras={"deviceId":"5CL2_9Uvi7_fXD-DVrKD2I","eventId":10,"sequenceNumber":10}; amp_d77757=442df63b-8674-4e7c-8c0a-6b1bb61a8554...1im226hrf.1im227r55.9.0.9; ok-ses-id=U6y0YOKMz+8awzD5vJTz2YuTNsj882UVygH29JaGD4mTGakhdUbg3cdediVORDHUZL0Fxvh5kGhHfrn5hoGCg7RCHwN7Geqm5btIGmZ3FKFBK9Rq9KinqSqfU5fLA1mc',
}

params = {
    'offset': '220',
    'limit': '20',
    't': '1741681265927',
}

response = requests.get(
    'https://www.oklink.com/api/explorer/v1/btc/transactionsNoRestrict',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
response.json()
# Out:
# {'code': 0,
#  'msg': '',
#  'detailMsg': '',
#  'data': {'total': 1164469547,
#   'hits': [{'hash': '3005a148d3aec2353a0885f37726617fcabca2d68e0e4cf6a76f50705392e864',
#     'blockHeight': 887294,
#     'blocktime': 1741680591,
#     'inputsCount': 1,
#     'inputsValue': 0.00100962,
#     'outputsCount': 4,
#     'outputsValue': 0.00100649,
#     'fee': 313,
#     'realTransferValue': 0.00100962,
#     'realTransferValueUsd': 81.26986670999999,
#     'index': 1508,
#     'blockHash': '000000000000000000024d2fc607504fa739a3873cb812f4a48f0f6ab8bffcf3',
#     'coinbase': False,
#     'size': 410,
#     'version': 2,
#     'doubleSpend': False,
#     'inputsValueSat': 0.00100962,
#     'outputsValueSat': 0.00100649,
#     'inputs': [{'prevBlockHash': '000000000000000000024d2fc607504fa739a3873cb812f4a48f0f6ab8bffcf3',
#       'prevAddresses': ['bc1pqa0ll5evz2vlzjdj5zwwjh6jsq8j3sxxqufqpk58q8ut7xd2zgasaxz8tf'],
#       'scriptType': 'P2TR',
#       'vinIndex': 0,
# ...

# %%
import base64

encoded_str = "LWIzMWItNDU0Ny05Mjk5LWI2ZDA3Yjc2MzFhYmEyYzkwM2NjfDI4NTI3OTgyMzQxODczNTg="
decoded_bytes = base64.b64decode(encoded_str)
decoded_str = decoded_bytes.decode('utf-8')  # 假设解码后的字节是UTF-8编码的文本
print(decoded_str)
# Out:
# -b31b-4547-9299-b6d07b7631aba2c903cc|2852798234187358
