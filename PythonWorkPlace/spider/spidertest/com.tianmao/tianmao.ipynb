# %%
import requests

cookies = {
    'DI_T_': '7VjQ9AVBpqKPZoK3VAh1Dco1dQxZDn6JWDEKTYezMWP961ke7jZ',
    't': 'bae5fcb2b8c7898db79845062815a42f',
    '_samesite_flag_': 'true',
    '3PcFlag': '1741340243594',
    'cookie2': '17642eadcf48a92b21eaf68dd2023a45',
    '_tb_token_': '369bee3f5555e',
    'xlly_s': '1',
    'sgcookie': 'E100BnfotMdeI9AVTVEc4rK4%2B9AiyLHHoxLERWKMvUWaI4QjGbLZf4pTT0qlQaRJrKughLU2fRr0SwBCk1EQ7qIRWIxRrCTtrLXy8xeD5WqmWDx4nY1PaCMyH7wKWlfKb0W7',
    'unb': '2217759732725',
    'sn': '%E7%95%85%E6%80%9D%E7%BB%B4%E9%80%9A%E4%BF%A1%E4%B8%93%E8%90%A5%E5%BA%97%3A%E5%B0%8F%E7%BF%BC',
    'uc1': 'cookie14=UoYaiuBpwVjlew%3D%3D&cookie21=W5iHLLyFfoaZ',
    'csg': '3c95488b',
    '_cc_': 'VT5L2FSpdA%3D%3D',
    'cancelledSubSites': 'empty',
    'skt': '10f48c63de36de93',
    '_m_h5_tk': 'eef985c9957dcd5ced4cbdbf28640f2e_1741348531413',
    '_m_h5_tk_enc': '3015a50adcfb9b1ad4334491061cbe44',
    '_euacm_ac_l_uid_': '2217759732725',
    '2217759732725_euacm_ac_c_uid_': '2216581751249',
    '2217759732725_euacm_ac_rs_uid_': '2216581751249',
    '_portal_version_': 'new',
    'cc_gray': '1',
    'XSRF-TOKEN': '68a426c7-c23f-42fe-aa01-d20d4db4073a',
    '_euacm_ac_rs_sid_': 'null',
    'cna': 'nW5EIPzi8ToCAXtYLMwkby/j',
    'JSESSIONID': '6713985200F8583F62011B4151D46E6A',
    'tfstk': 'gIzZU91u2NQZDBUNnX02YATQ2f3tNVXSSrMjiSVm1ADiChM4uvPl6AsAX-rUnJnsI56TLnP4UlMg1Gnc38NlBjsTGtRT888X5OITiEujoT65PaNT1q3VFbsq1fOtGjOMsKiDx20jgT_3uXPT6qdpOKj7x5p276Zziq2m-2crwqYinEfExbGmoFmDSHDnpj0moAYMtWc-_jDmnEfUtvhqod2mjAGrnYTEacfq2hgsR_-mjYViLEYywfmGxW-XWFLI1cMoxx8mOylZbYVg5WRHMX4Q80iBG933wkwiT472-VozjRl39t8rIuN--v2DQ9GLjRzn0y1vwY4Ttz3nAafztye_6yPXiZcQFvVTSq7lwVuiIVzsfpt3T0Hi4Pmps3Nn7Aou74bJIxZQarl4ktQUU5qunoSy6Khh_haYbKxqjXhEF65Uxp48P5k5o4tvDcEKTY1O6nKxjXhEF65eDnntyXk561C..',
}

headers = {
    'authority': 'sycm.taobao.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="99", "Google Chrome";v="99"',
    'sycm-referer': '/mc/free/market_rank',
    'bx-v': '2.5.28',
    'sec-ch-ua-mobile': '?0',
    'onetrace-card-id': '%2Fmc%2Ffree%2Fmarket_rank%7C%E5%B8%82%E5%9C%BA%E6%8E%92%E8%A1%8C-%E5%95%86%E5%93%81-%E5%95%86%E5%93%81%E6%8E%92%E8%A1%8C',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36',
    'sec-ch-ua-platform': '"Windows"',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://sycm.taobao.com/mc/free/market_rank?activeKey=item&dateRange=2025-02-28%7C2025-03-06&dateType=recent7&parentCateId=50004958&cateId=150401&cateFlag=2',
    'accept-language': 'zh-CN,zh;q=0.9',
    # 'cookie': 'DI_T_=7VjQ9AVBpqKPZoK3VAh1Dco1dQxZDn6JWDEKTYezMWP961ke7jZ; t=bae5fcb2b8c7898db79845062815a42f; _samesite_flag_=true; 3PcFlag=1741340243594; cookie2=17642eadcf48a92b21eaf68dd2023a45; _tb_token_=369bee3f5555e; xlly_s=1; sgcookie=E100BnfotMdeI9AVTVEc4rK4%2B9AiyLHHoxLERWKMvUWaI4QjGbLZf4pTT0qlQaRJrKughLU2fRr0SwBCk1EQ7qIRWIxRrCTtrLXy8xeD5WqmWDx4nY1PaCMyH7wKWlfKb0W7; unb=2217759732725; sn=%E7%95%85%E6%80%9D%E7%BB%B4%E9%80%9A%E4%BF%A1%E4%B8%93%E8%90%A5%E5%BA%97%3A%E5%B0%8F%E7%BF%BC; uc1=cookie14=UoYaiuBpwVjlew%3D%3D&cookie21=W5iHLLyFfoaZ; csg=3c95488b; _cc_=VT5L2FSpdA%3D%3D; cancelledSubSites=empty; skt=10f48c63de36de93; _m_h5_tk=eef985c9957dcd5ced4cbdbf28640f2e_1741348531413; _m_h5_tk_enc=3015a50adcfb9b1ad4334491061cbe44; _euacm_ac_l_uid_=2217759732725; 2217759732725_euacm_ac_c_uid_=2216581751249; 2217759732725_euacm_ac_rs_uid_=2216581751249; _portal_version_=new; cc_gray=1; XSRF-TOKEN=68a426c7-c23f-42fe-aa01-d20d4db4073a; _euacm_ac_rs_sid_=null; cna=nW5EIPzi8ToCAXtYLMwkby/j; JSESSIONID=6713985200F8583F62011B4151D46E6A; tfstk=gIzZU91u2NQZDBUNnX02YATQ2f3tNVXSSrMjiSVm1ADiChM4uvPl6AsAX-rUnJnsI56TLnP4UlMg1Gnc38NlBjsTGtRT888X5OITiEujoT65PaNT1q3VFbsq1fOtGjOMsKiDx20jgT_3uXPT6qdpOKj7x5p276Zziq2m-2crwqYinEfExbGmoFmDSHDnpj0moAYMtWc-_jDmnEfUtvhqod2mjAGrnYTEacfq2hgsR_-mjYViLEYywfmGxW-XWFLI1cMoxx8mOylZbYVg5WRHMX4Q80iBG933wkwiT472-VozjRl39t8rIuN--v2DQ9GLjRzn0y1vwY4Ttz3nAafztye_6yPXiZcQFvVTSq7lwVuiIVzsfpt3T0Hi4Pmps3Nn7Aou74bJIxZQarl4ktQUU5qunoSy6Khh_haYbKxqjXhEF65Uxp48P5k5o4tvDcEKTY1O6nKxjXhEF65eDnntyXk561C..',
}

params = {
    'dateRange': '2025-02-28|2025-03-06',
    'dateType': 'recent7',
    'pageSize': '10',
    'page': '6',
    'cateId': '150401',
    'rankType': 'gmv',
    'minPrice': '',
    'maxPrice': '',
    'priceSeg': '1',
    'sellerType': '-1',
    'cateFlag': '2',
    'indexCode': 'payByrCnt,uv',
    'marketVersion': 'free',
    '_': '1741340294898',
    'token': '26d757fe6',
}

response = requests.get(
    'https://sycm.taobao.com/mc/mq/mkt/item/offline/rank.json',
    params=params,
    cookies=cookies,
    headers=headers,
).json()
print(response)
