# %%
import requests
import execjs
json_data = {
    'eid': '',
    'achievementQueryType': 'and',
    'achievementQueryDto': [],
    'personnelQueryDto': {
        'queryType': 'and',
    },
    'aptitudeQueryDto': {
        'queryType': 'and',
        'nameStr': '',
        'aptitudeQueryType': 'and',
        'businessScopeQueryType': 'or',
        'filePlaceType': '1',
        'aptitudeDtoList': [
            {
                'codeStr': '',
                'queryType': 'and',
                'aptitudeType': 'qualification',
            },
        ],
        'aptitudeSource': 'new',
    },
    'page': {
        'page': 5,
        'limit': 20,
        'field': '',
        'order': '',
    },
}


result = execjs.compile(open('test.js', 'r', encoding='utf-8').read()).call('get_sign', json_data)

print(result)

cookies = {
    'Hm_lvt_03b8714a30a2e110b8a13db120eb6774': '1741331609',
    'HMACCOUNT': 'BAB68826AE7F198E',
    'HWWAFSESTIME': '1741331608066',
    'HWWAFSESID': 'bfede94f4ad7221189',
    'Hm_lpvt_03b8714a30a2e110b8a13db120eb6774': '1741331828',
}

headers = {
    'authority': 'capi.jiansheku.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="99", "Google Chrome";v="99"',
    'page': 'search-enterprise',
    'devicetype': 'PC',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36',
    'content-type': 'application/json;charset=UTF-8',
    'accept': 'application/json, text/plain, */*',
    'timestamp': str(result['timestamp']),
    'sign': result['sign'],
    'sec-ch-ua-platform': '"Windows"',
    'origin': 'https://www.jiansheku.com',
    'sec-fetch-site': 'same-site',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.jiansheku.com/',
    'accept-language': 'zh-CN,zh;q=0.9',
    # 'cookie': 'Hm_lvt_03b8714a30a2e110b8a13db120eb6774=1741331609; HMACCOUNT=BAB68826AE7F198E; HWWAFSESTIME=1741331608066; HWWAFSESID=bfede94f4ad7221189; Hm_lpvt_03b8714a30a2e110b8a13db120eb6774=1741331828',
}



response = requests.post('https://capi.jiansheku.com/nationzj/enterprice/page', cookies=cookies, headers=headers, json=json_data).json()

print(response)
# Out:
# {'timestamp': 1741339936084, 'sign': '00f7d6a3b5bdaece6df50aa6ac3a369a'}
# ...
