# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
# 绘制折线图

# %%
x = np.arange(-5,11) 
y =  2  * x +  5

# %%
plt.plot(x,y)
plt.title('test')
plt.show()

# %%
plt.plot(x,y)
plt.title('样例')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26679 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 20363 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26679 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 20363 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 方法一：指定字体

# %%
# 中文部分，需指定 fontproperties=font

# %%
ls
# Out:
# 4-1 折线图.ipynb                  4-5 subplots.ipynb
# 4-2  条形图与直方图.ipynb         4-6 字体设置.ipynb
# 4-3 Series 画图.ipynb             SimHei.ttf
# 4-4 DataFrame 画图.ipynb

# %%
from matplotlib.font_manager import FontProperties

# %%
font = FontProperties(fname='SimHei.ttf',size=15)

# %%
plt.plot(x,y)
plt.title('样例',fontproperties=font)
plt.xlabel('x轴',fontproperties=font)
plt.ylabel('y轴',fontproperties=font)
plt.show()

# %%
# 指定字体

# %%
# 方法二：替换显示字体

# %%
font_list = sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])

# %%
font_list
# Out:
# ['.Aqua Kana',
#  '.Arabic UI Display',
#  '.Arabic UI Text',
#  '.Helvetica Neue DeskInterface',
#  '.Keyboard',
#  '.LastResort',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
# ...

# %%
# 如果是在 windows下，可使用 Microsoft YaHei / SimHei / Song / STFangsong


plt.rcParams['font.family'] = ['Songti SC']

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
plt.plot(x,y)

plt.title('测试样例',fontsize=20)
plt.xlabel('x轴',fontsize=20)
plt.ylabel('y轴',fontsize=20)

plt.show()
